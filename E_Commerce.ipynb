# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import warnings

# %%
import os

# %%
df1 = pd.read_csv("amazon-products.csv")
df2 = pd.read_csv("shopee-products.csv")
df3 = pd.read_csv("walmart-products.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 55 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   timestamp             1000 non-null   object
#  1   title                 1000 non-null   object
#  2   seller_name           826 non-null    object
#  3   brand                 999 non-null    object
#  4   description           998 non-null    object
#  5   initial_price         814 non-null    object
#  6   final_price           997 non-null    object
#  7   currency              1000 non-null   object
#  8   availability          994 non-null    object
#  9   reviews_count         1000 non-null   int64
#  10  categories            1000 non-null   object
#  11  asin                  1000 non-null   object
#  12  buybox_seller         926 non-null    object
#  13  number_of_sellers     984 non-null    float64
#  14  root_bs_rank          999 non-null    float64
# ...

# %%
df1.describe()
# Out:
#        reviews_count  number_of_sellers  root_bs_rank  answered_questions  \
# count    1000.000000         984.000000  9.990000e+02          969.000000
# mean     3248.816000           4.116870  1.548019e+05            6.684211
# std     11888.210293           7.040037  3.395340e+05           34.550917
# min         1.000000           1.000000  3.000000e+01            0.000000
# 25%       129.000000           1.000000  1.014050e+04            0.000000
# 50%       461.500000           2.000000  3.982700e+04            0.000000
# 75%      1934.250000           4.000000  1.417780e+05            0.000000
# max    243907.000000          76.000000  3.931721e+06          723.000000
#
#        images_count  video_count       rating  bought_past_month      bs_rank  \
# count   1000.000000  1000.000000  1000.000000         204.000000   106.000000
# mean       2.808000     0.362000     4.401900         304.656863    78.047170
# ...

# %%
df1.head()
# Out:
#                  timestamp                                              title  \
# 0  2023-08-08 00:00:00.000              Saucony Men's Kinvara 13 Running Shoe
# 1  2023-08-09 00:00:00.000  Kishigo Premium Black Series Heavy Duty Unisex...
# 2  2024-02-04 00:00:00.000  TWINSLUXES Solar Post Cap Lights Outdoor - Wat...
# 3  2024-06-09 00:00:00.000  Accutire MS-4021B Digital Tire Pressure Gauge ...
# 4  2024-01-16 00:00:00.000  SAURA LIFE SCIENCE Adivasi Ayurvedic Neelgiri ...
#
#              seller_name               brand  \
# 0           Orv███tor███             Saucony
# 1           Ama███.co███             Kishigo
# 2           Twi███uxe███          TWINSLUXES
# 3  Cit███ran███Dir██████            Accutire
# 4     PRA███ EN███PRI███  SAURA LIFE SCIENCE
#
#                                          description          initial_price  \
# 0  When it comes to lightweight speed, nothing cr...                    NaN
# ...

# %%
df1.shape
# Out:
# (1000, 55)

# %%
df1.isnull().sum()
# Out:
# timestamp                  0
# title                      0
# seller_name              174
# brand                      1
# description                2
# initial_price            186
# final_price                3
# currency                   0
# availability               6
# reviews_count              0
# categories                 0
# asin                       0
# buybox_seller             74
# number_of_sellers         16
# root_bs_rank               1
# answered_questions        31
# domain                     0
# images_count               0
# url                        0
# video_count                0
# image_url                  5
# item_weight              247
# rating                     0
# product_dimensions        67
# seller_id                  0
# date_first_available      79
# discount                 179
# model_number             108
# manufacturer              30
# department               338
# plus_content               0
# upc                      901
# ...

# %%
df1.tail()
# Out:
#                    timestamp  \
# 995  2023-08-19 00:00:00.000
# 996  2023-08-15 00:00:00.000
# 997  2024-06-10 00:00:00.000
# 998  2024-05-28 00:00:00.000
# 999  2024-03-03 00:00:00.000
#
#                                                  title  \
# 995  Madison Park Amherst Faux Silk Comforter Set-C...
# 996  BIC Gel-Ocity Gel Pens, Medium Point Retractab...
# 997  Elmer's E842L Carpenter's Interior Wood Filler...
# 998  Office Chair Mat for Carpet, 30” x 48” Transpa...
# 999  Bavilk Kids Bike Helmet,Boys Girls Helmet Mult...
#
#                     seller_name         brand  \
# 995                Ama███.co███  Madison Park
# 996                Ama███.co███           BIC
# 997  Cer███ied███ole█████████ly       Elmer's
# 998                Hom███Lif███         HOMEK
# 999                Bav███Dir███        Bavilk
#
#                                            description          initial_price  \
# 995  The Madison Park Amherst 7 Piece Comforter Set...               "154.99"
# ...

# %%
df1.columns
# Out:
# Index(['timestamp', 'title', 'seller_name', 'brand', 'description',
#        'initial_price', 'final_price', 'currency', 'availability',
#        'reviews_count', 'categories', 'asin', 'buybox_seller',
#        'number_of_sellers', 'root_bs_rank', 'answered_questions', 'domain',
#        'images_count', 'url', 'video_count', 'image_url', 'item_weight',
#        'rating', 'product_dimensions', 'seller_id', 'date_first_available',
#        'discount', 'model_number', 'manufacturer', 'department',
#        'plus_content', 'upc', 'video', 'top_review', 'variations', 'delivery',
#        'features', 'format', 'buybox_prices', 'parent_asin', 'input_asin',
#        'ingredients', 'origin_url', 'bought_past_month', 'is_available',
#        'root_bs_category', 'bs_category', 'bs_rank', 'badge',
#        'subcategory_rank', 'amazon_choice', 'images', 'product_details',
#        'prices_breakdown', 'country_of_origin'],
#       dtype='object')

# %%
df1.describe(include='object')
# Out:
#                       timestamp                                         title  \
# count                      1000                                          1000
# unique                      141                                           999
# top     2023-08-09 00:00:00.000  Skechers Women's Go Joy Walking Shoe Sneaker
# freq                         55                                             2
#
#          seller_name     brand              description initial_price  \
# count            826       999                      998           814
# unique           569       894                      995           484
# top     Ama███.co███  Skechers  Previous page Next page       "19.99"
# freq             224        11                        2            16
#
#        final_price currency availability  \
# count          997     1000          994
# unique         667        3           74
# top        "19.99"      USD     In Stock
# freq            22      967          591
#
# ...

# %%
sns.heatmap(df1.isnull(), cbar=True)
plt.show()

# %%
sns.countplot(df1)
plt.show()

# %%
sns.boxplot(df1)
plt.show()

# %%
sns.pairplot(df1)
plt.show()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 37 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   url                                1000 non-null   object
#  1   id                                 1000 non-null   int64
#  2   title                              1000 non-null   object
#  3   sold                               1000 non-null   int64
#  4   rating                             1000 non-null   float64
#  5   reviews                            1000 non-null   int64
#  6   initial_price                      1000 non-null   float64
#  7   final_price                        1000 non-null   float64
#  8   currency                           1000 non-null   object
#  9   stock                              121 non-null    float64
#  10  favorite                           1000 non-null   int64
# ...

# %%
df2.describe()
# Out:
#                  id    sold       rating  reviews  initial_price  \
# count  1.000000e+03  1000.0  1000.000000   1000.0   1.000000e+03
# mean   1.994156e+10     0.0     2.391700      0.0   3.185189e+05
# std    6.102381e+09     0.0     2.404667      0.0   3.528405e+06
# min    1.003032e+08     0.0     0.000000      0.0   7.800000e-01
# 25%    1.692461e+10     0.0     0.000000      0.0   4.042250e+02
# 50%    2.206209e+10     0.0     1.000000      0.0   1.182150e+04
# 75%    2.453183e+10     0.0     4.900000      0.0   7.919025e+04
# max    2.995442e+10     0.0     5.000000      0.0   1.000000e+08
#
#         final_price  stock  favorite  video  seller_rating  seller_products  \
# count  1.000000e+03  121.0    1000.0    0.0     1000.00000      1000.000000
# mean   2.701780e+05    0.0       0.0    NaN        3.39621      1903.302000
# std    3.397457e+06    0.0       0.0    NaN        2.05004      9595.354899
# ...

# %%
df2.head()
# Out:
#                                                  url           id  \
# 0  https://shopee.com.mx/Camisa-Denim-Top-Retro-M...  21873056212
# 1  https://shopee.com.mx/Sylvanian-Families-Happy...  28600553970
# 2  https://shopee.cl/Dispositivo-De-Rescate-Para-...  18974847565
# 3  https://shopee.co.id/(CUCI-GUDANG)-Sprei-Batan...  26453475612
# 4  https://shopee.cl/Hombres-MAAP-Worlds-Pro-Hex-...  21567708790
#
#                                                title  sold  rating  reviews  \
# 0  Camisa Denim Top Retro Mujer Estilo Hong Kong ...     0     0.0        0
# 1  Sylvanian Families Happy Breakfast toy set Chi...     0     0.0        0
# 2  Dispositivo De Rescate Para Adultos Y Niños Po...     0     5.0        0
# 3  (CUCI GUDANG) Sprei Batangan Ukuran 180x200 Ba...     0     4.5        0
# 4  Hombres MAAP Worlds Pro Hex Jersey De Manga Co...     0     0.0        0
#
#    initial_price  final_price currency  stock  ...  category_id flash_sale  \
# ...

# %%
df2.tail()
# Out:
#                                                    url           id  \
# 995  https://shopee.com.my/MUSTELA-Organic-Certifie...   7334900298
# 996  https://shopee.co.id/WINOD---Tyra-Flatshoes-/-...  12317309346
# 997  https://shopee.com.my/Shieldtox-Multi-Insect-K...  19035307001
# 998  https://shopee.co.id/Buy-1-Pepsodent-Complete-...   9996579284
# 999  https://shopee.com.co/Figura-De-Acci%C3%B3n-La...  11686707544
#
#                                                  title  sold  rating  reviews  \
# 995  MUSTELA Organic Certified Stretch Marks Oil fo...     0     5.0        0
# 996  WINOD - Tyra Flatshoes / Sepatu Kantor Wanita ...     0     4.8        0
# 997  Shieldtox Multi-Insect Killer Spray Aerosol (5...     0     4.9        0
# 998  Buy 1 Pepsodent Complete 8 Plus Whitening  Fre...     0     4.9        0
# 999    Figura De Acción La Aventura De Tintín set 6pcs     0     0.0        0
#
#      initial_price  final_price currency  stock  ...  category_id flash_sale  \
# ...

# %%
df2.shape
# Out:
# (1000, 37)

# %%
df2.isnull().sum()
# Out:
# url                                     0
# id                                      0
# title                                   0
# sold                                    0
# rating                                  0
# reviews                                 0
# initial_price                           0
# final_price                             0
# currency                                0
# stock                                 879
# favorite                                0
# image                                   0
# video                                1000
# seller_name                             0
# shop_url                                0
# breadcrumb                              0
# Product Specifications                 14
# Product Description                     4
# seller_rating                           0
# seller_products                         0
# seller_chats_responded_percentage       0
# seller_chat_time_reply                604
# ...

# %%
sns.heatmap(df2.isnull(), cbar=True)
plt.show()

# %%
sns.countplot(df2)
plt.show()

# %%
sns.boxplot(df2)
plt.show()

# %%
sns.pairplot(df2)
plt.show()

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 44 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   timestamp               1000 non-null   object
#  1   url                     1000 non-null   object
#  2   final_price             1000 non-null   float64
#  3   sku                     1000 non-null   int64
#  4   currency                1000 non-null   object
#  5   gtin                    999 non-null    float64
#  6   specifications          1000 non-null   object
#  7   image_urls              1000 non-null   object
#  8   top_reviews             1000 non-null   object
#  9   rating_stars            1000 non-null   object
#  10  related_pages           991 non-null    object
#  11  available_for_delivery  1000 non-null   bool
#  12  available_for_pickup    1000 non-null   bool
#  13  brand                   1000 non-null   object
# ...

# %%
df3.describe()
# Out:
#        final_price           sku          gtin  review_count    product_id  \
# count   1000.00000  1.000000e+03  9.990000e+02   1000.000000  1.000000e+03
# mean      37.98634  2.203601e+09  5.786768e+11    465.027000  2.203601e+09
# std       97.48094  1.987681e+09  2.640686e+11   2049.842999  1.987681e+09
# min        0.91000  1.029102e+07  1.111102e+10      1.000000  1.029102e+07
# 25%       13.96000  5.576833e+08  4.620225e+11      9.000000  5.576833e+08
# 50%       19.99000  1.446916e+09  7.024018e+11     47.000000  1.446916e+09
# 75%       35.97000  3.769058e+09  7.651449e+11    206.500000  3.769058e+09
# max     1685.99000  6.925859e+09  9.931881e+11  43691.000000  6.925859e+09
#
#                 upc       rating  unit_price  initial_price
# count  9.990000e+02  1000.000000  101.000000     898.000000
# mean   5.786768e+11     4.338800   12.234287      61.535278
# std    2.640686e+11     0.703825   30.482208     165.317442
# ...

# %%
df3.head()
# Out:
#                  timestamp                                                url  \
# 0  2024-08-24 00:00:00.000  https://www.walmart.com/ip/Laura-Mercier-Cavia...
# 1  2024-08-24 00:00:00.000  https://www.walmart.com/ip/Exultantex-Grey-Bla...
# 2  2024-08-24 00:00:00.000  https://www.walmart.com/ip/Jessica-London-Wome...
# 3  2024-08-24 00:00:00.000  https://www.walmart.com/ip/100-Cotton-King-Per...
# 4  2024-08-25 00:00:00.000  https://www.walmart.com/ip/Disney-Boys-Graphic...
#
#    final_price         sku currency          gtin  \
# 0        22.90   173530386      USD  7.361501e+11
# 1        47.88   430528189      USD  7.710779e+11
# 2        33.24  6013308220      USD  4.651920e+11
# 3        49.99   161657830      USD  8.407081e+11
# 4        12.99  5397071399      USD  4.600086e+11
#
#                                       specifications  \
# 0  [{"name":"Brand","value":"Laura Mercier"},{"na...
# 1  [{"name":"Brand","value":"Exultantex"},{"name"...
# ...

# %%
df3.tail()
# Out:
#                    timestamp  \
# 995  2024-08-24 00:00:00.000
# 996  2024-08-24 00:00:00.000
# 997  2024-08-24 00:00:00.000
# 998  2024-08-25 00:00:00.000
# 999  2024-08-25 00:00:00.000
#
#                                                    url  final_price  \
# 995  https://www.walmart.com/ip/Great-Value-Sugar-F...         2.08
# 996  https://www.walmart.com/ip/TheLovely-Men-Women...        13.49
# 997  https://www.walmart.com/ip/Alpine-Swiss-Womens...        16.99
# 998  https://www.walmart.com/ip/Sunnycome-Retractab...        32.39
# 999  https://www.walmart.com/ip/Summer-Toddler-Girl...         9.89
#
#             sku currency          gtin  \
# 995   637751827      USD  7.874204e+10
# 996  5494180543      USD  7.366411e+11
# 997   578943868      USD  8.171371e+11
# 998  5286825403      USD  7.644797e+11
# 999   669112285      USD  7.686594e+11
#
#                                         specifications  \
# 995  [{"name":"Drink Mix Type","value":"Juice Drink...
# ...

# %%
df3.shape
# Out:
# (1000, 44)

# %%
df3.columns
# Out:
# Index(['timestamp', 'url', 'final_price', 'sku', 'currency', 'gtin',
#        'specifications', 'image_urls', 'top_reviews', 'rating_stars',
#        'related_pages', 'available_for_delivery', 'available_for_pickup',
#        'brand', 'breadcrumbs', 'category_ids', 'review_count', 'description',
#        'product_id', 'product_name', 'review_tags', 'category_url',
#        'category_name', 'category_path', 'root_category_url',
#        'root_category_name', 'upc', 'tags', 'main_image', 'rating',
#        'unit_price', 'unit', 'aisle', 'free_returns', 'sizes', 'colors',
#        'seller', 'other_attributes', 'customer_reviews', 'ingredients',
#        'initial_price', 'discount', 'ingredients_full', 'categories'],
#       dtype='object')

# %%
df3.isnull().sum()
# Out:
# timestamp                   0
# url                         0
# final_price                 0
# sku                         0
# currency                    0
# gtin                        1
# specifications              0
# image_urls                  0
# top_reviews                 0
# rating_stars                0
# related_pages               9
# available_for_delivery      0
# available_for_pickup        0
# brand                       0
# breadcrumbs                 0
# category_ids                0
# review_count                0
# description                 1
# product_id                  0
# product_name                0
# review_tags                 0
# category_url                0
# category_name               0
# category_path               0
# root_category_url           0
# root_category_name          0
# upc                         1
# tags                      213
# main_image                  0
# rating                      0
# unit_price                899
# ...

# %%
sns.heatmap(df3.isnull(), cbar=True)
plt.show()

# %%
sns.countplot(df3)
plt.show()

# %%
sns.boxplot(df3)
plt.show()

# %%
sns.pairplot(df3)
plt.show()
