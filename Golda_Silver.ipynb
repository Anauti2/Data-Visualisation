# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
import os
import re

# %%
df1 =pd.read_csv("Gold.csv")
df2 = pd.read_csv("Silver.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11626 entries, 0 to 11625
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    11626 non-null  object
#  1   USD     11626 non-null  object
#  2   EUR     11626 non-null  object
#  3   JPY     11624 non-null  object
#  4   GBP     11626 non-null  object
#  5   CAD     11624 non-null  object
#  6   CHF     11624 non-null  object
#  7   INR     11624 non-null  object
#  8   CNY     10055 non-null  object
#  9   TRY     10581 non-null  object
#  10  SAR     11624 non-null  object
#  11  IDR     11624 non-null  object
#  12  AED     11624 non-null  object
#  13  THB     11624 non-null  object
#  14  VND     8775 non-null   object
#  15  EGP     9035 non-null   object
#  16  KRW     11624 non-null  object
#  17  RUB     7965 non-null   object
#  18  ZAR     11624 non-null  object
#  19  AUD     11624 non-null  object
# dtypes: object(20)
# memory usage: 1.8+ MB

# %%
df1.describe()
# Out:
#              Date    USD    EUR       JPY    GBP    CAD    CHF       INR  \
# count       11626  11626  11626     11624  11626  11624  11624     11624
# unique      11626   5572   5615     11168   4933   6078   6608     10908
# top     7/21/2023  383.0  309.4  92,421.3  229.5  527.9  505.3  12,513.4
# freq            1     21     16         4     18     15     13         5
#
#             CNY    TRY      SAR          IDR      AED       THB           VND  \
# count     10055  10581    11624        11624    11624     11624          8775
# unique     8886   6092     8624        11229     8410     10825          8445
# top     2,260.4    0.1  1,383.0  2,020,580.9  1,410.4  14,789.9  29,302,313.5
# freq          6    575       10            4       10         5             4
#
#           EGP          KRW       RUB      ZAR    AUD
# count    9035        11624      7965    11624  11624
# unique   7470        11215      7534     9768   6355
# ...

# %%
df1.head()
# Out:
#          Date    USD    EUR       JPY    GBP    CAD    CHF      INR  CNY  TRY  \
# 0  12/29/1978  226.0  137.1       NaN  110.7    NaN    NaN      NaN  NaN  NaN
# 1    1/1/1979  226.0  137.1       NaN  110.7    NaN    NaN      NaN  NaN  NaN
# 2    1/2/1979  226.8  137.3  43,164.9  111.5  263.7  359.6  1,792.9  NaN  NaN
# 3    1/3/1979  218.6  134.0  43,717.9  108.0  264.4  365.9  1,802.2  NaN  NaN
# 4    1/4/1979  223.2  136.8  43,674.9  110.7  264.1  366.4  1,811.7  NaN  NaN
#
#      SAR        IDR    AED      THB  VND  EGP        KRW  RUB    ZAR    AUD
# 0    NaN        NaN    NaN      NaN  NaN  NaN        NaN  NaN    NaN    NaN
# 1    NaN        NaN    NaN      NaN  NaN  NaN        NaN  NaN    NaN    NaN
# 2  735.6  138,160.5  851.3  4,454.6  NaN  NaN  107,470.0  NaN  194.6  193.6
# 3  739.4  138,877.0  855.7  4,477.7  NaN  NaN  108,027.4  NaN  192.2  193.0
# 4  743.4  139,616.3  860.3  4,501.5  NaN  NaN  108,602.5  NaN  193.0  194.6

# %%
df1.tail()
# Out:
#             Date      USD      EUR        JPY      GBP      CAD      CHF  \
# 11621  7/17/2023  1,949.6  1,735.6  270,624.0  1,491.1  2,568.8  1,677.6
# 11622  7/18/2023  1,975.0  1,761.0  274,742.3  1,515.2  2,604.6  1,697.5
# 11623  7/19/2023  1,975.4  1,765.0  275,818.1  1,530.2  2,602.1  1,698.0
# 11624  7/20/2023  1,976.1  1,776.4  277,563.0  1,537.5  2,604.5  1,714.5
# 11625  7/21/2023  1,960.6  1,762.5  277,758.2  1,524.7  2,590.3  1,697.3
#
#              INR       CNY       TRY      SAR           IDR      AED  \
# 11621  159,940.3  13,982.7  51,361.4  7,315.3  29,228,403.2  7,160.9
# 11622  162,067.1  14,192.0  53,214.8  7,410.0  29,621,050.0  7,254.2
# 11623  162,141.7  14,273.3  52,910.5  7,409.9  29,616,422.6  7,255.7
# 11624  162,159.4  14,193.1  53,022.9  7,412.8  29,681,022.0  7,258.2
# 11625  160,788.8  14,093.0  52,814.6  7,354.6  29,461,936.2  7,201.3
#
#             THB           VND       EGP          KRW        RUB       ZAR  \
# ...

# %%
df1.shape
# Out:
# (11626, 20)

# %%
df1.isnull().sum()
# Out:
# Date       0
# USD        0
# EUR        0
# JPY        2
# GBP        0
# CAD        2
# CHF        2
# INR        2
# CNY     1571
# TRY     1045
# SAR        2
# IDR        2
# AED        2
# THB        2
# VND     2851
# EGP     2591
# KRW        2
# RUB     3661
# ZAR        2
# AUD        2
# dtype: int64

# %%
sns.heatmap(df1.isnull(), cbar=True)
plt.show()

# %%
df1 = pd.DataFrame(np.random.rand(10,4))

# %%
df1
# Out:
#           0         1         2         3
# 0  0.910906  0.702145  0.489951  0.664274
# 1  0.666784  0.773467  0.065492  0.442685
# 2  0.581677  0.533145  0.466574  0.028388
# 3  0.985743  0.477993  0.210307  0.920414
# 4  0.092646  0.390417  0.736720  0.335188
# 5  0.839591  0.051245  0.770785  0.601329
# 6  0.999770  0.058231  0.036701  0.629472
# 7  0.832270  0.660807  0.848939  0.765073
# 8  0.997736  0.552929  0.557068  0.708740
# 9  0.777891  0.069158  0.278906  0.248177

# %%
df1.plot.bar()
# Out:
# <Axes: >

# %%
df1.plot.barh()
# Out:
# <Axes: >

# %%
sns.scatterplot(df1,)
# Out:
# <Axes: >

# %%
df1.plot(kind='hist', stacked=True, bins=15,figsize= (5,8))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1
# Out:
#           0         1         2         3
# 0  0.910906  0.702145  0.489951  0.664274
# 1  0.666784  0.773467  0.065492  0.442685
# 2  0.581677  0.533145  0.466574  0.028388
# 3  0.985743  0.477993  0.210307  0.920414
# 4  0.092646  0.390417  0.736720  0.335188
# 5  0.839591  0.051245  0.770785  0.601329
# 6  0.999770  0.058231  0.036701  0.629472
# 7  0.832270  0.660807  0.848939  0.765073
# 8  0.997736  0.552929  0.557068  0.708740
# 9  0.777891  0.069158  0.278906  0.248177

# %%
df1.hist()
# Out:
# array([[<Axes: title={'center': '0'}>, <Axes: title={'center': '1'}>],
#        [<Axes: title={'center': '2'}>, <Axes: title={'center': '3'}>]],
#       dtype=object)

# %%
pd.plotting.scatter_matrix(df1, figsize= (10,5))
# Out:
# array([[<Axes: xlabel='0', ylabel='0'>, <Axes: xlabel='1', ylabel='0'>,
#         <Axes: xlabel='2', ylabel='0'>, <Axes: xlabel='3', ylabel='0'>],
#        [<Axes: xlabel='0', ylabel='1'>, <Axes: xlabel='1', ylabel='1'>,
#         <Axes: xlabel='2', ylabel='1'>, <Axes: xlabel='3', ylabel='1'>],
#        [<Axes: xlabel='0', ylabel='2'>, <Axes: xlabel='1', ylabel='2'>,
#         <Axes: xlabel='2', ylabel='2'>, <Axes: xlabel='3', ylabel='2'>],
#        [<Axes: xlabel='0', ylabel='3'>, <Axes: xlabel='1', ylabel='3'>,
#         <Axes: xlabel='2', ylabel='3'>, <Axes: xlabel='3', ylabel='3'>]],
#       dtype=object)

# %%
plt.plot((1,2,3),(4,5,9),'g*-')

# %%
df1.plot(kind = 'hist' , stacked = True , bins = 15 , figsize = (5,8) , title = "histogram of iris")
# Out:
# <Axes: title={'center': 'histogram of iris'}, ylabel='Frequency'>

# %%
df1
# Out:
#           0         1         2         3
# 0  0.910906  0.702145  0.489951  0.664274
# 1  0.666784  0.773467  0.065492  0.442685
# 2  0.581677  0.533145  0.466574  0.028388
# 3  0.985743  0.477993  0.210307  0.920414
# 4  0.092646  0.390417  0.736720  0.335188
# 5  0.839591  0.051245  0.770785  0.601329
# 6  0.999770  0.058231  0.036701  0.629472
# 7  0.832270  0.660807  0.848939  0.765073
# 8  0.997736  0.552929  0.557068  0.708740
# 9  0.777891  0.069158  0.278906  0.248177

# %%
df1.hist(figsize= (5,10) , color = '#166600' , alpha  = .9, sharex=False)
# Out:
# array([[<Axes: title={'center': '0'}>, <Axes: title={'center': '1'}>],
#        [<Axes: title={'center': '2'}>, <Axes: title={'center': '3'}>]],
#       dtype=object)

# %%
np.random.seed(100)
df1 = pd.DataFrame(np.random.rand(1000,1) , index=pd.date_range('2021-07-18' , periods=1000), columns=['data'])

# %%
df1
# Out:
#                 data
# 2021-07-18  0.543405
# 2021-07-19  0.278369
# 2021-07-20  0.424518
# 2021-07-21  0.844776
# 2021-07-22  0.004719
# ...              ...
# 2024-04-08  0.656403
# 2024-04-09  0.291456
# 2024-04-10  0.150869
# 2024-04-11  0.036932
# 2024-04-12  0.597964
#
# [1000 rows x 1 columns]

# %%
df1['data1'] = df.data.cumsum()

# %%
df1
# Out:
#                 data       data1
# 2021-07-18  0.543405    0.543405
# 2021-07-19  0.278369    0.821774
# 2021-07-20  0.424518    1.246292
# 2021-07-21  0.844776    2.091068
# 2021-07-22  0.004719    2.095787
# ...              ...         ...
# 2024-04-08  0.656403  497.103821
# 2024-04-09  0.291456  497.395277
# 2024-04-10  0.150869  497.546146
# 2024-04-11  0.036932  497.583078
# 2024-04-12  0.597964  498.181042
#
# [1000 rows x 2 columns]

# %%
d = df1.iloc[0]

# %%
d
# Out:
# data     0.543405
# data1    0.543405
# Name: 2021-07-18 00:00:00, dtype: float64

# %%
iris = df1.head(3).T

# %%
df1.head(3)
# Out:
#                 data     data1
# 2021-07-18  0.543405  0.543405
# 2021-07-19  0.278369  0.821774
# 2021-07-20  0.424518  1.246292

# %%
df1.iloc[0:4].plot.pie(subplots = True , figsize = (20,20) ,fontsize = 10 , autopct = '%.3f')
# Out:
# array([<Axes: ylabel='data'>, <Axes: ylabel='data1'>], dtype=object)

# %%
pd.plotting.scatter_matrix(df1 , figsize = (15,15))
# Out:
# array([[<Axes: xlabel='data', ylabel='data'>,
#         <Axes: xlabel='data1', ylabel='data'>],
#        [<Axes: xlabel='data', ylabel='data1'>,
#         <Axes: xlabel='data1', ylabel='data1'>]], dtype=object)

# %%
pd.plotting.scatter_matrix(df1 , figsize = (10,10), diagonal='kde')
# Out:
# array([[<Axes: xlabel='data', ylabel='data'>,
#         <Axes: xlabel='data1', ylabel='data'>],
#        [<Axes: xlabel='data', ylabel='data1'>,
#         <Axes: xlabel='data1', ylabel='data1'>]], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3],[4,5,9],'r--')

plt.show()

# %%
plt.plot([1,2,3],[4,5,9],'g*-',)

# %%
plt.plot([1,2,3],[4,5,9],'b*',linestyle='dashed',markersize=15)

# %%
import matplotlib.pyplot as plt
x=[5,7,12]
y=[6,2,13]
plt.plot(x,y)
plt.title('Plotting lines')
plt.ylabel('Age')
plt.xlabel('Salary')
plt.savefig('test_pie.jpg')

# %%
x=np.arange(0, 4*np.pi, 0.1)
y=np.sin(x)
plt.plot(x,y)
plt.title("Sine wave")
# Out:
# Text(0.5, 1.0, 'Sine wave')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 625 entries, 0 to 624
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    625 non-null    object
#  1   Price   625 non-null    float64
#  2   Open    625 non-null    float64
#  3   High    625 non-null    float64
#  4   Low     625 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 24.5+ KB

# %%
df2 = pd.DataFrame(np.random.rand(10,4))

# %%
df2
# Out:
#           0         1         2         3
# 0  0.027732  0.382237  0.953251  0.222199
# 1  0.305126  0.819320  0.578470  0.027617
# 2  0.954388  0.312139  0.184073  0.016470
# 3  0.524061  0.166957  0.812942  0.002834
# 4  0.099238  0.423371  0.005809  0.643928
# 5  0.525890  0.249089  0.271195  0.058806
# 6  0.960190  0.160912  0.794558  0.415414
# 7  0.129655  0.056637  0.196956  0.046800
# 8  0.902222  0.837372  0.478282  0.127724
# 9  0.340763  0.460902  0.179879  0.521011

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
df2.plot(kind = 'hist' , stacked = True , bins = 15 , figsize = (5,8) , title = "histogram of iris")
# Out:
# <Axes: title={'center': 'histogram of iris'}, ylabel='Frequency'>

# %%
df2
# Out:
#           0         1         2         3
# 0  0.027732  0.382237  0.953251  0.222199
# 1  0.305126  0.819320  0.578470  0.027617
# 2  0.954388  0.312139  0.184073  0.016470
# 3  0.524061  0.166957  0.812942  0.002834
# 4  0.099238  0.423371  0.005809  0.643928
# 5  0.525890  0.249089  0.271195  0.058806
# 6  0.960190  0.160912  0.794558  0.415414
# 7  0.129655  0.056637  0.196956  0.046800
# 8  0.902222  0.837372  0.478282  0.127724
# 9  0.340763  0.460902  0.179879  0.521011

# %%
df2.hist()
# Out:
# array([[<Axes: title={'center': '0'}>, <Axes: title={'center': '1'}>],
#        [<Axes: title={'center': '2'}>, <Axes: title={'center': '3'}>]],
#       dtype=object)

# %%
df2.hist(figsize= (5,10) , color = '#166600' , alpha  = .9, sharex=False)
# Out:
# array([[<Axes: title={'center': '0'}>, <Axes: title={'center': '1'}>],
#        [<Axes: title={'center': '2'}>, <Axes: title={'center': '3'}>]],
#       dtype=object)

# %%
np.random.seed(100)
df2 = pd.DataFrame(np.random.rand(1000,1) , index=pd.date_range('2021-07-18' , periods=1000), columns=['data'])

# %%
df2
# Out:
#                 data
# 2021-07-18  0.543405
# 2021-07-19  0.278369
# 2021-07-20  0.424518
# 2021-07-21  0.844776
# 2021-07-22  0.004719
# ...              ...
# 2024-04-08  0.656403
# 2024-04-09  0.291456
# 2024-04-10  0.150869
# 2024-04-11  0.036932
# 2024-04-12  0.597964
#
# [1000 rows x 1 columns]

# %%
df2['data1'] = df.data.cumsum()

# %%
df2
# Out:
#                 data       data1
# 2021-07-18  0.543405    0.543405
# 2021-07-19  0.278369    0.821774
# 2021-07-20  0.424518    1.246292
# 2021-07-21  0.844776    2.091068
# 2021-07-22  0.004719    2.095787
# ...              ...         ...
# 2024-04-08  0.656403  497.103821
# 2024-04-09  0.291456  497.395277
# 2024-04-10  0.150869  497.546146
# 2024-04-11  0.036932  497.583078
# 2024-04-12  0.597964  498.181042
#
# [1000 rows x 2 columns]

# %%
d = df2.iloc[0]

# %%
d
# Out:
# data     0.543405
# data1    0.543405
# Name: 2021-07-18 00:00:00, dtype: float64

# %%
d.plot.pie(figsize = (10,10))
# Out:
# <Axes: ylabel='2021-07-18 00:00:00'>

# %%
df2 = d.head(3).T

# %%
df2.head(3)
# Out:
# data     0.543405
# data1    0.543405
# Name: 2021-07-18 00:00:00, dtype: float64

# %%
df2.iloc[0:4].plot.pie(subplots = True , figsize = (20,20) ,fontsize = 10 , autopct = '%.3f')
# Out:
# array([<Axes: ylabel='2021-07-18 00:00:00'>], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3],[4,5,9],'r--')

plt.show()

# %%
plt.plot([1,2,3],[4,5,9],'g*-',)

# %%
plt.plot([1,2,3],[4,5,9],'b*',linestyle='dashed',markersize=15)

# %%
import matplotlib.pyplot as plt
x=[5,7,12]
y=[6,2,13]
plt.plot(x,y)
plt.title('Plotting lines')
plt.ylabel('Age')
plt.xlabel('Salary')
plt.savefig('test_pie.jpg')

# %%
x=np.arange(0, 4*np.pi, 0.1)
y=np.sin(x)
plt.plot(x,y)
plt.title("Sine wave")
# Out:
# Text(0.5, 1.0, 'Sine wave')
